# %%
#POS (Part-of-Speech) Tagging Practica

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
text="this is pos tag practical"

# %%
result=word_tokenize(text)

# %%
lower_word = []
for i in result:
    print(i)
    lowerw = i.lower()
    print(lowerw)
    lower_word.append(lowerw)
# Out:
# this
# this
# is
# is
# pos
# pos
# tag
# tag
# practical
# practical

# %%
result=word_tokenize(text)

# %%
lower_word = []
for i in result:
    print(i)
