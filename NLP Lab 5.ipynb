# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\admin\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\admin\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('Averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Error loading Averaged_perceptron_tagger_eng: Package
# [nltk_data]     'Averaged_perceptron_tagger_eng' not found in index
# False

# %%
from nltk import pos_tag

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.chunk import ne_chunk

# %%
nltk.download(svgling)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 nltk.download(svgling)
#
# NameError: name 'svgling' is not defined

# %%
pip install svgling
# Out:
# Requirement already satisfied: svgling in c:\users\admin\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: svgwrite in c:\users\admin\anaconda3\lib\site-packages (from svgling) (1.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
text="my name is shivam nangare and i am from kharadi"

# %%
tokens= words_tokenize(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 tokens= words_tokenize(text)
#
# NameError: name 'words_tokenize' is not defined

# %%
tokens
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 tokens
#
# NameError: name 'tokens' is not defined

# %%
pos=pos_tag(tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pos=pos_tag(tokens)
#
# NameError: name 'tokens' is not defined

# %%
pos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 pos
#
# NameError: name 'pos' is not defined

# %%
ner=ne_chunk(pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 ner=ne_chunk(pos)
#
# NameError: name 'pos' is not defined

# %%
ner
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 ner
#
# NameError: name 'ner' is not defined

# %%
# !pip install -q nltk svgling

import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.chunk import ne_chunk

# Download required NLTK resources
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('words')
nltk.download('maxent_ne_chunker_tab')

# Input text
text = "My name is Shivam Nangare and I am from Kharadi."

# Tokenization
tokens = word_tokenize(text)
print("Tokens:")
print(tokens)

# Part-of-Speech tagging
pos = pos_tag(tokens)
print("\nPOS Tags:")
print(pos)

# Named Entity Recognition
ner = ne_chunk(pos)
print("\nNamed Entities:")
print(ner)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# Tokens:
# ['My', 'name', 'is', 'Shivam', 'Nangare', 'and', 'I', 'am', 'from', 'Kharadi', '.']
#
# POS Tags:
# [('My', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Shivam', 'NNP'), ('Nangare', 'NNP'), ('and', 'CC'), ('I', 'PRP'), ('am', 'VBP'), ('from', 'IN'), ('Kharadi', 'NNP'), ('.', '.')]
#
# Named Entities:
# (S
#   My/PRP$
#   name/NN
#   is/VBZ
#   (PERSON Shivam/NNP Nangare/NNP)
#   and/CC
#   I/PRP
#   am/VBP
#   from/IN
#   (GPE Kharadi/NNP)
#   ./.)

# %%
ner
