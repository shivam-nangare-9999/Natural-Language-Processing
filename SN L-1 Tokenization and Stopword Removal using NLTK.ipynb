# %%
#Tokenization and stopword using NLTK

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize , sent_tokenize

# %%
corpra = """
Welcome to RTMSSU Pune center. this is the class TYCT . Lets go!!!!!"""

# %%
sent_tokenize(corpra)
# Out:
# ['\nWelcome to RTMSSU Pune center.',
#  'this is the class TYCT .',
#  'Lets go!!!!',
#  '!']

# %%
word_tokenize(corpra)
# Out:
# ['Welcome',
#  'to',
#  'RTMSSU',
#  'Pune',
#  'center',
#  '.',
#  'this',
#  'is',
#  'the',
#  'class',
#  'TYCT',
#  '.',
#  'Lets',
#  'go',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!']

# %%
#stopword

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Input text
text = "This is a simple example of Natural Language Processing."

# %%
# Tokenize the text
words = word_tokenize(text)

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))

# %%
# Remove stopwords
filtered_words = [word for word in words if word.lower() not in stop_words]

# %%
print("Original Text:")
print(text)
# Out:
# Original Text:
# This is a simple example of Natural Language Processing.

# %%
print("\nAfter Stopword Removal:")
print(filtered_words)
# Out:
# After Stopword Removal:
# ['simple', 'example', 'Natural', 'Language', 'Processing', '.']
